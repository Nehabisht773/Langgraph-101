# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from typing import TypedDict

# %%
load_dotenv()
model = ChatOpenAI()

# %%
class BlogState(TypedDict):
    
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    #fetch title
    title = state['title']

    #call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    #update state
    state['outline'] = outline
    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    
    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title -{title} using the following outline \n {outline}'
    content = model.invoke(prompt).content
    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

#add modes 
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog',  create_blog)

#edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
initial_state = {'title': 'Rise of AI in India'}
final_state = workflow.invoke(initial_state)
print(final_state['content'])
# Out:
# Artificial Intelligence (AI) technology has been making significant strides in revolutionizing various industries across the globe. With the ability to process vast amounts of data, learn from patterns, and make decisions autonomously, AI has the potential to transform the way businesses operate and improve efficiency and effectiveness in a wide range of sectors. In recent years, the rise of AI in India has been particularly notable, with the country emerging as a key player in the global AI landscape.
#
# The current landscape of AI in India is evolving rapidly, with several major players like Infosys, Tata Consultancy Services (TCS), and Wipro leading the charge in developing cutting-edge AI solutions. Additionally, several startups and research institutes have emerged in the Indian AI ecosystem, contributing to the growth and innovation in this field. The adoption of AI technology in sectors such as healthcare, finance, agriculture, and manufacturing is also on the rise, with companies leveraging AI to improve decision-making, enhance productivity, and drive business outcomes.
#
# There are several factors contributing to the rise of AI in India. Government policies and initiatives promoting AI technology, such as the National AI Strategy and the National AI Portal, are providing a conducive environment for the growth of AI technology in the country. Additionally, the growing investments and funding in the Indian AI industry, along with the availability of a skilled workforce and talent pool in the field of AI, are fueling the expansion of AI capabilities in India.
#
# The applications of AI in India are diverse and impactful. In the healthcare industry, AI is being used for diagnosing diseases, treatment planning, and powering telemedicine platforms to improve access to healthcare services. In the finance industry, AI-driven trading algorithms and personalized financial services are transforming the way financial institutions operate and serve their customers. In the agriculture industry, AI-powered tools for precision farming and crop yield prediction using AI algorithms are helping farmers improve crop management practices and increase productivity.
#
# Despite the promising prospects of AI in India, there are several challenges and opportunities that need to be addressed. Data privacy and security concerns, regulatory challenges surrounding AI technology, and the potential impact of AI on job displacement and upskilling are some of the key challenges that need to be navigated. However, there are ample opportunities for growth and innovation in the AI industry in India, with the potential to drive economic growth, create new job opportunities, and foster collaboration and partnerships in advancing AI technology.
#
# Looking towards the future, the prospects of AI in India are promising. Predictions indicate that AI technology will continue to evolve and be integrated into various sectors, creating new opportunities for growth and innovation. Collaboration and partnerships between government, industry, academia, and other stakeholders will be crucial in advancing AI technology in India and ensuring that the country remains at the forefront of AI innovation.
#
# In conclusion, the rise of AI in India is reshaping the way businesses operate, industries function, and society interacts with technology. With the right policies, investments, talent, and collaboration, India has the potential to become a global leader in AI technology. As we move forward, it is important for all stakeholders to stay informed and engaged in the development of AI technology in India, to ensure a sustainable and inclusive future for AI innovation in the country.
